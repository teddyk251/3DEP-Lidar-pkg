# %%
import pdal
import json
import sys
import geopandas as gpd
from shapely.geometry import Polygon
from shapely.geometry import Point
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
import geopandas as gpd
from shapely.geometry import Polygon

MINX, MINY, MAXX, MAXY = [-93.756155, 41.918015, -93.747334, 41.921429]
polygon = Polygon(((MINX, MINY), (MINX, MAXY),
                  (MAXX, MAXY), (MAXX, MINY), (MINX, MINY)))

grid = gpd.GeoDataFrame([polygon], columns=["geometry"])

# %%
import os
sys.path.append(os.path.abspath(os.path.join('../src')))

# %%
from data_fetcher import DataFetcher
from vis import Vis

# %%
df = DataFetcher(polygon=polygon, region="IA_FullState", epsg="4326")
# Out:
# Pipeline Template loaded successfully

# %%
df.fetch_data()

# %%
elevation_geodf = df.get_elevation_geodf()
cloud_points = df.cloud_points

# %%
vis = Vis(elevation_geodf=elevation_geodf, cloud_points=cloud_points)

# %%
vis.get_scatter_plot()
# Out:
# <module 'matplotlib.pyplot' from '/home/teddy/anaconda3/envs/pda/lib/python3.10/site-packages/matplotlib/pyplot.py'>

# %%
vis.get_terrain_map()
# Out:
# <module 'matplotlib.pyplot' from '/home/teddy/anaconda3/envs/pda/lib/python3.10/site-packages/matplotlib/pyplot.py'>
